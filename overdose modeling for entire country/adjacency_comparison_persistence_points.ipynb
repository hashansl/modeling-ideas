# %% [markdown]
# #### Comparing persistence points

# %%
# Import libraries

import numpy as np
import pandas as pd
import geopandas as gpd
# Out:
# /Users/h6x/anaconda3/envs/TDA/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
selected_variables_for_state = ['EP_POV','EP_UNEMP','EP_PCI','EP_NOHSDP','EP_UNINSUR','EP_AGE65','EP_AGE17','EP_DISABL','EP_SNGPNT','EP_LIMENG','EP_MINRTY','EP_MUNIT','EP_MOBILE','EP_CROWD','EP_NOVEH','EP_GROUPQ']

# %%
quantile_100 = pd.read_csv('/Users/h6x/ORNL/git/modeling-ideas/overdose modeling for entire country/results/test/summary_df_full_data.csv')
quantile_75 = pd.read_csv('/Users/h6x/ORNL/git/modeling-ideas/overdose modeling for entire country/results/test/summary_df_q75_data.csv')
quantile_50 = pd.read_csv('/Users/h6x/ORNL/git/modeling-ideas/overdose modeling for entire country/results/test/summary_df_q50_data.csv')

# %%
quantile_100
# Out:
#        county  census_c    variable    H0   H1  No Persistence
# 0       50001        10      EP_POV  10.0  1.0           False
# 1       50001        10    EP_UNEMP  10.0  2.0           False
# 2       50001        10      EP_PCI  10.0  0.0           False
# 3       50001        10   EP_NOHSDP  10.0  2.0           False
# 4       50001        10  EP_UNINSUR  10.0  0.0           False
# ...       ...       ...         ...   ...  ...             ...
# 50219   47181         4    EP_MUNIT   4.0  0.0           False
# 50220   47181         4   EP_MOBILE   4.0  0.0           False
# 50221   47181         4    EP_CROWD   4.0  0.0           False
# 50222   47181         4    EP_NOVEH   4.0  0.0           False
# 50223   47181         4   EP_GROUPQ   3.0  0.0           False
#
# [50224 rows x 6 columns]

# %%
temp_df = quantile_100[quantile_100['variable'] == 'EP_MUNIT']

# %%
temp_df
# Out:
#        county  census_c  variable    H0   H1  No Persistence
# 11      50001        10  EP_MUNIT   7.0  1.0           False
# 27      50003        12  EP_MUNIT   8.0  1.0           False
# 43      50005        10  EP_MUNIT   9.0  1.0           False
# 59      50007        34  EP_MUNIT  32.0  2.0           False
# 75      50009         3  EP_MUNIT   3.0  0.0           False
# ...       ...       ...       ...   ...  ...             ...
# 50155   47153         3  EP_MUNIT   3.0  0.0           False
# 50171   47159         5  EP_MUNIT   4.0  0.0           False
# 50187   47161         3  EP_MUNIT   3.0  0.0           False
# 50203   47173         4  EP_MUNIT   4.0  0.0           False
# 50219   47181         4  EP_MUNIT   4.0  0.0           False
#
# [3139 rows x 6 columns]

# %%
# get the number of rows in the dataframe that H1 >=9
temp_df[temp_df['No Persistence'] == True].shape[0]
# Out:
# 241

# %%
for variable in selected_variables_for_state:

    print('Variable: ', variable)

    # temp_df = quantile_75[quantile_75['variable'] == variable]['H1']
    # print(temp_df.value_counts())


    temp_df = quantile_75[quantile_75['variable'] == variable]

    print(len(temp_df))

    # temp_df = temp_df[temp_df['H1'] >= 9]
    temp_df =temp_df[temp_df['No Persistence'] == True]
    print(temp_df.shape[0])

    # break
# Out:
# Variable:  EP_POV
# 3139
# 487
# Variable:  EP_UNEMP
# 3139
# 508
# Variable:  EP_PCI
# 3139
# 301
# Variable:  EP_NOHSDP
# 3139
# 648
# Variable:  EP_UNINSUR
# 3139
# 515
# Variable:  EP_AGE65
# 3139
# 952
# Variable:  EP_AGE17
# 3139
# 383
# Variable:  EP_DISABL
# 3139
# 921
# Variable:  EP_SNGPNT
# 3139
# 363
# Variable:  EP_LIMENG
# 3139
# 389
# Variable:  EP_MINRTY
# 3139
# 375
# Variable:  EP_MUNIT
# 3139
# 265
# Variable:  EP_MOBILE
# 3139
# 1204
# Variable:  EP_CROWD
# 3139
# 481
# Variable:  EP_NOVEH
# 3139
# 410
# Variable:  EP_GROUPQ
# 3139
# 662

# %%
quantile_100
# Out:
#        county  census_c    variable    H0   H1  No Persistence
# 0       50001        10      EP_POV  10.0  1.0           False
# 1       50001        10    EP_UNEMP  10.0  2.0           False
# 2       50001        10      EP_PCI  10.0  0.0           False
# 3       50001        10   EP_NOHSDP  10.0  2.0           False
# 4       50001        10  EP_UNINSUR  10.0  0.0           False
# ...       ...       ...         ...   ...  ...             ...
# 50219   47181         4    EP_MUNIT   4.0  0.0           False
# 50220   47181         4   EP_MOBILE   4.0  0.0           False
# 50221   47181         4    EP_CROWD   4.0  0.0           False
# 50222   47181         4    EP_NOVEH   4.0  0.0           False
# 50223   47181         4   EP_GROUPQ   3.0  0.0           False
#
# [50224 rows x 6 columns]

# %%
quantile_75
# Out:
#        county  census_c    variable    H0   H1  No Persistence
# 0       50001        10      EP_POV  10.0  1.0           False
# 1       50001        10    EP_UNEMP   9.0  2.0           False
# 2       50001        10      EP_PCI   7.0  0.0           False
# 3       50001        10   EP_NOHSDP  10.0  2.0           False
# 4       50001        10  EP_UNINSUR   9.0  0.0           False
# ...       ...       ...         ...   ...  ...             ...
# 50219   47181         4    EP_MUNIT   4.0  0.0           False
# 50220   47181         4   EP_MOBILE   NaN  NaN            True
# 50221   47181         4    EP_CROWD   3.0  0.0           False
# 50222   47181         4    EP_NOVEH   3.0  0.0           False
# 50223   47181         4   EP_GROUPQ   1.0  0.0           False
#
# [50224 rows x 6 columns]

# %%
quantile_50
# Out:
#        county  census_c    variable   H0   H1  No Persistence
# 0       50001        10      EP_POV  6.0  0.0           False
# 1       50001        10    EP_UNEMP  3.0  0.0           False
# 2       50001        10      EP_PCI  2.0  0.0           False
# 3       50001        10   EP_NOHSDP  4.0  0.0           False
# 4       50001        10  EP_UNINSUR  4.0  0.0           False
# ...       ...       ...         ...  ...  ...             ...
# 50219   47181         4    EP_MUNIT  4.0  0.0           False
# 50220   47181         4   EP_MOBILE  NaN  NaN            True
# 50221   47181         4    EP_CROWD  2.0  0.0           False
# 50222   47181         4    EP_NOVEH  NaN  NaN            True
# 50223   47181         4   EP_GROUPQ  NaN  NaN            True
#
# [50224 rows x 6 columns]

# %%
# for each variable in the quantile_100 dataframe plot H1 histogram
import matplotlib.pyplot as plt
import seaborn as sns

for variable in selected_variables_for_state:

    temp_df = quantile_100[quantile_100['variable'] == variable]
    sns.histplot(temp_df['H1'])
    plt.title('Histogram of ' + variable + ' for quantile_100')
    plt.show()
# Out:
# /Users/h6x/anaconda3/envs/TDA/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/h6x/anaconda3/envs/TDA/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/h6x/anaconda3/envs/TDA/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
svi_od = gpd.read_file(f'/Users/h6x/ORNL/git/modeling-ideas/overdose modeling for entire country/data/processed data/svi with hepvu/2018/SVI2018 census tracts with death rate HepVu-5 classes/{state}/{state}.shp')
